# %% [markdown]
# # Jupyter Notebook
# ## Um belo jupyter notebook
# 1. Histograma épico
# 2. Olá, mundo!

# %% [markdown]
# Importando as bibliotecas utilizadas

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Gerando 100000 dados aleátorios centradoos em 1 com desvio padrão de 6

# %%
data = np.random.normal(1,6,10000)

# %% [markdown]
# Gerando o gráfico

# %%
plt.hist(data, 50)
plt.show()

# %% [markdown]
# Imprimindo olá mundo

# %%
print("olá, mundo! ")
# Out:
# olá, mundo!
